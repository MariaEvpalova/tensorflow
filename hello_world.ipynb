# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaEvpalova/tensorflow/blob/main/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.9.2

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# Train the model
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 6.4047
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2248
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2928
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5557
# Epoch 5/500
# 1/1 [==============================] - 0s 16ms/step - loss: 2.9722
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5095
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1420
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8494
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6158
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4287
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2783
# Epoch 12/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1568
# ...

# %%
# Make a prediction
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 189ms/step
# [[18.98384]]

# %%
xa = np.arange (1.0, 1001.0)

# %%
def house_model():
    xs = np.array(xa, dtype='float')
    ys = np.array([0.5+0.5*i for i in xs], dtype='float')
    model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
    model.compile(optimizer='sgd', loss='mean_squared_error')
    model.fit(xs, ys, epochs=1000)
    return model

# %%
model = house_model()
# Out:
# Epoch 1/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 2/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 3/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 4/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 5/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 6/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 7/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 8/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 9/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 10/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 11/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# Epoch 12/1000
# 32/32 [==============================] - 0s 2ms/step - loss: nan
# ...

# %%
new_y = 7.0
prediction = model.predict([new_y])[0]
print(prediction)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# [nan]
